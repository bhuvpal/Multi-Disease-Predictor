# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\bhuvp\Downloads\archive (9)\Cancer.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.drop(columns=['id'],inplace=True)

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
# df['diagnosis'] = [1 if value=='M' esle 0 for value in df.diagnosis]

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
sns.barplot(data=df['diagnosis'].value_counts())
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df.drop(columns=['texture_se','smoothness_se','symmetry_se','fractal_dimension_se'],inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'perimeter_se', 'area_se', 'compactness_se',
#        'concavity_se', 'concave_points_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x = df.iloc[:,1:]
y = df['diagnosis']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
x.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'perimeter_se', 'area_se', 'compactness_se',
#        'concavity_se', 'concave_points_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
'''for i in x.columns:
    sns.distplot(df[i])
    plt.show()'''
# Out:
# 'for i in x.columns:\n    sns.distplot(df[i])\n    plt.show()'

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.24,random_state=42)

# %%
ss = StandardScaler()

# %%
ss.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = ss.transform(x_train)
x_test = ss.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
df.index==568
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
import pickle

# %%
pickle.dump(lg,open('BreastCancer1.pkl','wb'))

# %%
x.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'perimeter_se', 'area_se', 'compactness_se',
#        'concavity_se', 'concave_points_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df[df.index==568].values
# Out:
# array([[0.000e+00, 7.760e+00, 2.454e+01, 4.792e+01, 1.810e+02, 5.263e-02,
#         4.362e-02, 0.000e+00, 0.000e+00, 1.587e-01, 5.884e-02, 3.857e-01,
#         2.548e+00, 1.915e+01, 4.660e-03, 0.000e+00, 0.000e+00, 9.456e+00,
#         3.037e+01, 5.916e+01, 2.686e+02, 8.996e-02, 6.444e-02, 0.000e+00,
#         0.000e+00, 2.871e-01, 7.039e-02]])

# %%
lg.predict_proba([[7.760, 24.54, 47.92, 181, 0.05263,
       0.04362, 0.0, 0.0, 0.1587, 0.05884, 0.03857,
       2.548, 19.15, 0.004660, 0.000, 0.000, 9.456,
       30.37, 59.16, 268.6, 0.08996, 0.06444, 0.0,
       0.00, 0.2871, 0.07039]])
# Out:
# array([[0., 1.]])

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'perimeter_se', 'area_se', 'compactness_se',
#        'concavity_se', 'concave_points_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.iloc[567,:]
# Out:
# diagnosis                     1.00000
# radius_mean                  20.60000
# texture_mean                 29.33000
# perimeter_mean              140.10000
# area_mean                  1265.00000
# smoothness_mean               0.11780
# compactness_mean              0.27700
# concavity_mean                0.35140
# concave_points_mean           0.15200
# symmetry_mean                 0.23970
# fractal_dimension_mean        0.07016
# radius_se                     0.72600
# perimeter_se                  5.77200
# area_se                      86.22000
# compactness_se                0.06158
# concavity_se                  0.07117
# concave_points_se             0.01664
# radius_worst                 25.74000
# texture_worst                39.42000
# perimeter_worst             184.60000
# area_worst                 1821.00000
# smoothness_worst              0.16500
# compactness_worst             0.86810
# concavity_worst               0.93870
# concave_points_worst          0.26500
# ...

# %%
from sklearn.svm import SVC

# %%
svc = SVC(probability=True)
svc.fit(x_train,y_train)
# Out:
# SVC(probability=True)

# %%
accuracy_score(y_test,svc.predict(x_test))*100
# Out:
# 96.35036496350365

# %%
accuracy_score(y_train,svc.predict(x_train))*100
# Out:
# 98.37962962962963

# %%
svc.predict_proba(ss.transform([[7.760, 24.54, 47.92, 181, 0.05263,
       0.04362, 0.0, 0.0, 0.1587, 0.05884, 0.03857,
       2.548, 19.15, 0.004660, 0.000, 0.000, 9.456,
       30.37, 59.16, 268.6, 0.08996, 0.06444, 0.0,
       0.00, 0.2871, 0.07039]]))
# Out:
# C:\Users\bhuvp\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.96767047, 0.03232953]])

# %%
pickle.dump(svc,open('BreastCancer2.pkl','wb'))

# %%
pickle.dump(ss,open('BreastScaler.pkl','wb'))
